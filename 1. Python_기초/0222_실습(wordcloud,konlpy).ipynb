# %%
# https://amueller.github.io/word_cloud/auto_examples/simple.html#sphx-glr-auto-examples-simple-py

# %%
text = 'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Aenean efficitur lorem justo, at faucibus velit dapibus a. Suspendisse potenti. Donec odio risus, accumsan sed fermentum non, lacinia nec justo. Aenean quis elit nec augue egestas ultricies. In elementum bibendum neque, quis luctus turpis vestibulum quis. In at leo et dolor vestibulum placerat. Sed nec interdum eros. Vivamus efficitur risus augue, in sollicitudin tortor sodales nec. Integer neque nulla, vulputate vel dictum a, tempor eget elit. Integer nisl mauris, ornare sit amet urna mattis, mattis rhoncus magna. In aliquet dolor urna, vel elementum turpis cursus vitae. Quisque pretium erat turpis, vel dapibus risus tincidunt a. Integer ut sapien ultrices, lobortis lectus eu, ullamcorper elit. Donec maximus dictum interdum. Curabitur sagittis risus diam, at porttitor odio dignissim eget. Aenean sem sapien, efficitur id placerat eu, elementum ac nulla. Sed placerat, velit quis aliquet consequat, ligula nibh interdum orci, eget aliquet urna massa nec arcu. Morbi fringilla orci eget consequat porta. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae; Vivamus rutrum dolor sed dolor cursus, euismod pulvinar magna rhoncus. Cras nec justo ultrices, ultricies ligula ac, ultrices quam.Maecenas id turpis eu ipsum consequat congue id sit amet arcu. Sed placerat feugiat pharetra. Donec scelerisque, mauris sit amet viverra condimentum, purus elit vulputate leo, suscipit dignissim turpis ipsum non felis. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Etiam consectetur nisi sed mi imperdiet porttitor. Pellentesque gravida leo quis mauris euismod, id pharetra mi rhoncus. Nulla imperdiet tincidunt mi, maximus tincidunt ipsum fringilla nec. Quisque venenatis, diam sit amet imperdiet eleifend, lectus tellus ultrices ante, eget pulvinar mauris erat sed felis. Sed sodales tincidunt aliquam. Pellentesque posuere egestas risus, et lobortis sapien tincidunt eu. Sed bibendum, lectus et viverra venenatis, nunc ipsum aliquam ipsum, nec interdum ante risus vel neque. Mauris in enim ac massa congue pretium. Donec id porta ante, id interdum velit. In tortor velit, finibus eu sem quis, sagittis vehicula turpis. In hac habitasse platea dictumst.Vivamus non cursus neque. Etiam bibendum mi placerat mauris auctor bibendum. Proin vel auctor justo. Nullam vitae pulvinar lectus. Nam non nunc pellentesque, scelerisque ante nec, sagittis felis. Aliquam erat volutpat. Mauris dapibus erat sit amet efficitur semper. Sed sapien nulla, placerat ut orci quis, dignissim facilisis enim. Praesent nec lobortis neque. Donec sed rhoncus massa, nec rutrum neque. Duis lacinia vel nisi eu aliquam.Sed quis tortor sem. Fusce dignissim sit amet nisl in euismod. Donec eget mauris non urna pharetra efficitur. Nam non mollis turpis, et convallis nibh. Aliquam porttitor orci non ligula eleifend, eget ullamcorper sapien vehicula. Sed ac venenatis est. Pellentesque urna nisi, rhoncus et ante non, eleifend dictum arcu. Phasellus a laoreet libero. Maecenas tempus pellentesque efficitur. In viverra tortor turpis, auctor imperdiet dolor mattis in'

# %%
import os

from os import path
from wordcloud import WordCloud

# %%
wordcloud = WordCloud().generate(text)

# %%
# Read the whole text.
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

#text = open(path.join(d, 'constitution.txt')).read() // text는 이미 불러왔으니 주석처리

# %%
# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('./WC.png', bbox_inches = 'tight') #bbox_inches = 'tight' :여백 최소화
# save 관련 내용은 print보다 앞에 두어야 함
#plt.svefig
#plt.show

# %%
# lower max_font_size 폰트 사이즈 조절
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# 이미지 뷰어로 바로 쓸 수 있음
#주피터 노트북 말고 cli 등 작업을 할 때 , 화면에 바로 띄울 수 없을 때 이미지를 볼 수 있음
# The pil way (if you don't have matplotlib)
# image = wordcloud.to_image()
# image.show()

# %%
text2 = '''The purpose of this study is to identify the characteristics of qualification test preparation lectures on Youtube using Reigeluth’s Elaboration theory, and suggest implications for developing lectures for Youtube. Three channels providing advanced level lectures for the Korean History Proficiency Test were selected, and the characteristics of lectures covering the Chosun dynasty were analyzed in terms of the seven strategies of the elaboration theory.
The main research results are as follows. First, in channel A, conceptual elaboration strategies were partially used in lectures, while learning prerequisite sequences were not. Summarization, synthesization, cognitive strategy activator, and other strategies were used in all lectures. In channel B's lectures, conceptual elaboration strategies were used in all lectures, while learning prerequisite sequences, summarization, and learner control strategies were not. In lectures of channel C, conceptual elaboration strategies were used for facilitating memory. Learning prerequisite sequences were used in only one lecture, and summarization, synthesization, and cognitive strategy activator strategies were used in all lectures. Looking at the similarities and differences of each channel, with the exception of channel C, learning prerequisite sequence strategies were not used, while cognitive strategy activators were frequently used compared to other strategies. Also, analogies were used to help learners comprehend concepts, and synthesizations were use to help explain relations between concepts. Summarizations and cognitive strategy activator strategies were used differently for each channel.
The implications of this study are: First, it is necessary to use learning prerequisite sequences to inform learners of prerequisite knowledge. Second, it is necessary to use the seven strategies in a way that reflects the trends of the test learners are preparing for. Third, when explaining concepts that are not currently used, it is necessary to use analogies familiar to learners. Fourth, synthesizations should be used to help learners grasp the relations between concepts. Fifth, the Youtube platform should be actively used to create positive responses from learners by including activities such as sharing, commenting, and recommending videos. For future research, it is necessary to analyze contents of test preparation lectures, expand similar study methods to other learning contents on Youtube. and examine the potential of Youtube as an educational platform.'''

# %%
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
import matplotlib.pyplot as plt
wordcloud = WordCloud().generate(text2)
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ---
# # wordcloud 한글깨짐현상 처리
#
# ---

# %% [markdown]
# # font_path : 폰트 파일의 경로
# # 폰트 찾기
#
# import matplotlib.font_manager as fm
# sys_font = fm.findSystemFonts()
#
# [f for f in sys_font if 'g' in f]

# %%
text3 = '''본 연구에서는 유튜브 자격증시험 대비용 강의를 정교화 이론으로 분석하여 그 특징과 시사점을 제시하는 데 목적이 있다. 이를 위해 한국사능력검정시험 대비 컨텐츠를 제공하는 3개 채널의 강의를 정교화 이론의 7가지 전략을 토대로 분석하였다. 주요 연구결과는 다음과 같다. 먼저 채널별 특징을 살펴보면, 채널 A의 강의에서는 개념적 정교화가 부분적으로 사용되고 있었고, 선수학습능력의 계열화는 사용되지 않고 있었다. 요약자와 종합자, 인지전략의 활성자 전략 등은 모든 강의에서 사용되고 있었다. 채널 B의 강의에서는 모든 강의에서 개념적 정교화가 사용되고 있는 반면에 선수학습능력의 계열화, 요약자, 학습자 통제 전략은 사용되지 않고 있었다. 채널 C의 강의에서는 ‘암기 포인트’ 요소로 개념적 정교화가 사용되었다. 선수학습능력의 계열화는 한 강의에서만 사용되었고, 모든 강의에 요약자와 종합자, 인지전략의 활성자 전략 등이 사용되었다. 채널별 유사점과 차이점을 살펴보면, 채널 C의 한 강의를 제외하고 선수학습능력의 계열화 전략이 거의 사용되지 않은 점, 다른 전략들에 비해 인지전략의 활성자가 가장 많이 사용된 점, 비유의 활용이 개념의 이해를 위해 사용된 점, 종합자의 사용이 개념간 관계 설명에 사용되고 있다는 유사점이 있었다. 요약자와 인지전략의 활성자 전략은 채널별로 사용 양식에 차이가 있었다.
연구결과를 통해 도출한 유튜브용 자격증대비 컨텐츠 제작에 관한 시사점은, 첫째, 학습자에게 필요한 선수지식을 알려주는 선수학습능력의 계열화 전략을 사용할 필요가 있다. 둘째, 유튜브용 자격증대비 컨텐츠를 제작할 때 해당 자격증에서 출제되는 경향을 고려해 정교화 7가지 전략을 사용할 필요가 있다. 셋째, 현재는 사용되지 않는 개념을 설명할 때 학습자에서 친숙한 단어로 비유하여 설명할 필요가 있다. 넷째, 단원과 단원이 독립적이지 않은 자격증 컨텐츠는 단원 종합자를 사용해 개념 사이의 연관성을 파악하도록 할 수 있다. 다섯째, 유튜브용 교육 컨텐츠 제작 시 유튜브 플랫폼을 적극적으로 활용해야 한다. 공유, 댓글, 추천 동영상 등 유튜브의 SNS 기능을 통해 상호작용할 때 학습자에게 좋은 반응을 얻을 수 있을 것이다. 후속 연구에서 다양한 교수설계이론의 관점에서 유튜브 시험 대비 컨텐츠를 분석하고, 유튜브 자격증 컨텐츠 외 교육적 컨텐츠에 관한 연구, 유튜브의 플랫폼적 특성을 교육에 적용하는 연구가 필요할 것으로 보인다.'''
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
import matplotlib.pyplot as plt

wordcloud = WordCloud(font_path=r"C:\\Windows\\Fonts\\batang.ttc").generate(text3)
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ---

# %%
# 오라클에서 jdk설치
# conda install -c conda forge jpye1
# pip install konlpy

# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint

# %%
kkma = Kkma()
kkma.sentences('네, 안녕하세요. 반갑습니다.')
# Out:
# ['네, 안녕하세요.', '반갑습니다.']

# %%
abst = kkma.sentences(text3)

# %%
abst
# Out:
# ['본 연구에서는 유 튜브 자격증시험 대비용 강의를 정교화 이론으로 분석하여 그 특징과 시사점을 제시하는 데 목적이 있다.',
#  '이를 위해 한국사능력 검정시험 대비 컨텐츠를 제공하는 3개 채널의 강의를 정교화 이론의 7가지 전략을 토대로 분석하였다.',
#  '주요 연구결과는 다음과 같다.',
#  '먼저 채널별 특징을 살펴보면, 채널 A의 강의에서는 개념적 정교 화가 부분적으로 사용되고 있었고, 선수학습능력의 계열화는 사용되지 않고 있었다.',
#  '요약자와 종 합자, 인지 전략의 활성자 전략 등은 모든 강의에서 사용되고 있었다.',
#  '채널 B의 강의에서는 모든 강의에서 개념적 정 교화가 사용되고 있는 반면에 선수학습능력의 계열화, 요약자, 학습자 통제 전략은 사용되지 않고 있었다.',
#  '채널 C의 강의에서는 ‘ 암 기 포인트’ 요소로 개념적 정 교화가 사용되었다.',
#  '선수학습능력의 계열화는 한 강의에서만 사용되었고, 모든 강의에 요약자와 종 합자, 인지 전략의 활성자 전략 등이 사용되었다.',
#  '채널별 유사점과 차이점을 살펴보면, 채널 C의 한 강의를 제외하고 선수학습능력의 계열화 전략이 거의 사용되지 않은 점, 다른 전략들에 비해 인지 전략의 활성 자가 가장 많이 사용된 점, 비유의 활용이 개념의 이해를 위해 사용된 점, 종합자의 사용이 개념 간 관계 설명에 사용되고 있다는 유사점이 있었다.',
#  '요약자와 인지 전략의 활성자 전략은 채널 별로 사용 양식에 차이가 있었다.',
#  '연구결과를 통해 도출한 유 튜브용 자격증대비 컨텐츠 제작에 관한 시사점은, 첫째, 학습자에게 필요한 선수지식을 알려주는 선수학습능력의 계열화 전략을 사용할 필요가 있다.',
#  '둘째, 유 튜브용 자격증대비 컨텐츠를 제작할 때 해당 자격증에서 출제되는 경향을 고려해 정 교화 7가지 전략을 사용할 필요가 있다.',
#  '셋째, 현재는 사용되지 않는 개념을 설명할 때 학습자에서 친숙한 단어로 비유하여 설명할 필요가 있다.',
# ...

# %%
from konlpy import tag
from konlpy.corpus import kolaw

# %%
examples = ['아버지가방에들어가신다',  # 띄어쓰기
            '나는 밥을 먹는다', u'하늘을 나는 자동차', # 중의성 해소
            '아이폰 기다리다 지쳐 애플공홈에서 언락폰질러버렸다 6+ 128기가실버ㅋ'] # 속어

# %%
kkma.sentences(examples[0]) # 문장 분석
# Out:
# ['아버지가방에 들어가신다']

# %%
kkma.morphs(examples[0]) # 형태소 분석
# Out:
# ['아버지', '가방', '에', '들어가', '시', 'ㄴ다']

# %%
kkma.nouns(examples[0]) #명사 분석
# Out:
# ['아버지', '아버지가방', '가방']

# %%
print(kkma.sentences(examples[1]))
print(kkma.morphs(examples[1]))
print(kkma.nouns(examples[1]))
# Out:
# ['나는 밥을 먹는다']
# ['나', '는', '밥', '을', '먹', '는', '다']
# ['나', '밥']

# %%
print(kkma.sentences(examples[2]))
print(kkma.morphs(examples[2])) # '나는- 의 동사원형인 날다가 추출됨'
print(kkma.nouns(examples[2]))
# Out:
# ['하늘을 나는 자동차']
# ['하늘', '을', '날', '는', '자동차']
# ['하늘', '자동차']

# %%
print(kkma.sentences(examples[3]))
print(kkma.morphs(examples[3])) # 지치 , 어 따로 나오는거 개신기함
print(kkma.nouns(examples[3]))
# Out:
# ['아이 폰 기다리다 지쳐 애플 공 홈에서 언락 폰 질러 버렸다 6+ 128 기가 실버 ㅋ']
# ['아이', '폰', '기다리', '다', '지치', '어', '애플', '공', '홈', '에서', '언락', '폰', '질르', '어', '버리', '었', '다', '6', '+', '128', '기가', '실버', 'ㅋ']
# ['아이', '아이폰', '폰', '애플', '애플공홈', '공', '홈', '언락', '언락폰', '6', '128', '128기가실버ㅋ', '기가', '실버', 'ㅋ']

# %%
ab_nouns = kkma.nouns(text3)

# %%
ab_target = ' '.join(ab_nouns)

# %%
wc = WordCloud(font_path=r"C:\\Windows\\Fonts\\batang.ttc").generate(ab_target)

# %%
# wc.generate(ab_target)

# %%
plt.imshow(wc)

# %% [markdown]
# ---
# # 불용어 처리
#
# ---

# %%
ignore_list = '''가
가까스로
가령
각
각각
각자
각종
갖고말하자면
같다
같이
개의치않고
거니와
거바
거의
것
것과 같이
것들
게다가
게우다
겨우
견지에서
결과에 이르다
결국
결론을 낼 수 있다
겸사겸사
고려하면
고로
곧
공동으로
과
과연
관계가 있다
관계없이
관련이 있다
관하여
관한
관해서는
구
구체적으로
구토하다
그
그들
그때
그래
그래도
그래서
그러나
그러니
그러니까
그러면
그러므로
그러한즉
그런 까닭에
그런데
그런즉
그럼
그럼에도 불구하고
그렇게 함으로써
그렇지
그렇지 않다면
그렇지 않으면
그렇지만
그렇지않으면
그리고
그리하여
그만이다
그에 따르는
그위에
그저
그중에서
그치지 않다
근거로
근거하여
기대여
기점으로
기준으로
기타
까닭으로
까악
까지
까지 미치다
까지도
꽈당
끙끙
끼익
나
나머지는
남들
남짓
너
너희
너희들
네
넷
년
논하지 않다
놀라다
누가 알겠는가
누구
다른
다른 방면으로
다만
다섯
다소
다수
다시 말하자면
다시말하면
다음
다음에
다음으로
단지
답다
당신
당장
대로 하다
대하면
대하여
대해 말하자면
대해서
댕그
더구나
더군다나
더라도
더불어
더욱더
더욱이는
도달하다
도착하다
동시에
동안
된바에야
된이상
두번째로
둘
둥둥
뒤따라
뒤이어
든간에
들
등
등등
딩동
따라
따라서
따위
따지지 않다
딱
때
때가 되어
때문에
또
또한
뚝뚝
라 해도
령
로
로 인하여
로부터
로써
륙
를
마음대로
마저
마저도
마치
막론하고
만 못하다
만약
만약에
만은 아니다
만이 아니다
만일
만큼
말하자면
말할것도 없고
매
매번
메쓰겁다
몇
모
모두
무렵
무릎쓰고
무슨
무엇
무엇때문에
물론
및
바꾸어말하면
바꾸어말하자면
바꾸어서 말하면
바꾸어서 한다면
바꿔 말하면
바로
바와같이
밖에 안된다
반대로
반대로 말하자면
반드시
버금
보는데서
보다더
보드득
본대로
봐
봐라
부류의 사람들
부터
불구하고
불문하고
붕붕
비걱거리다
비교적
비길수 없다
비로소
비록
비슷하다
비추어 보아
비하면
뿐만 아니라
뿐만아니라
뿐이다
삐걱
삐걱거리다
사
삼
상대적으로 말하자면
생각한대로
설령
설마
설사
셋
소생
소인
솨
쉿
습니까
습니다
시각
시간
시작하여
시초에
시키다
실로
심지어
아
아니
아니나다를가
아니라면
아니면
아니었다면
아래윗
아무거나
아무도
아야
아울러
아이
아이고
아이구
아이야
아이쿠
아하
아홉
안 그러면
않기 위하여
않기 위해서
알 수 있다
알았어
앗
앞에서
앞의것
야
약간
양자
어
어기여차
어느
어느 년도
어느것
어느곳
어느때
어느쪽
어느해
어디
어때
어떠한
어떤
어떤것
어떤것들
어떻게
어떻해
어이
어째서
어쨋든
어쩔수 없다
어찌
어찌됏든
어찌됏어
어찌하든지
어찌하여
언제
언젠가
얼마
얼마 안 되는 것
얼마간
얼마나
얼마든지
얼마만큼
얼마큼
엉엉
에
에 가서
에 달려 있다
에 대해
에 있다
에 한하다
에게
에서
여
여기
여덟
여러분
여보시오
여부
여섯
여전히
여차
연관되다
연이서
영
영차
옆사람
예
예를 들면
예를 들자면
예컨대
예하면
오
오로지
오르다
오자마자
오직
오호
오히려
와
와 같은 사람들
와르르
와아
왜
왜냐하면
외에도
요만큼
요만한 것
요만한걸
요컨대
우르르
우리
우리들
우선
우에 종합한것과같이
운운
월
위에서 서술한바와같이
위하여
위해서
윙윙
육
으로
으로 인하여
으로서
으로써
을
응
응당
의
의거하여
의지하여
의해
의해되다
의해서
이
이 되다
이 때문에
이 밖에
이 외에
이 정도의
이것
이곳
이때
이라면
이래
이러이러하다
이러한
이런
이럴정도로
이렇게 많은 것
이렇게되면
이렇게말하자면
이렇구나
이로 인하여
이르기까지
이리하여
이만큼
이번
이봐
이상
이어서
이었다
이와 같다
이와 같은
이와 반대로
이와같다면
이외에도
이용하여
이유만으로
이젠
이지만
이쪽
이천구
이천육
이천칠
이천팔
인 듯하다
인젠
일
일것이다
일곱
일단
일때
일반적으로
일지라도
임에 틀림없다
입각하여
입장에서
잇따라
있다
자
자기
자기집
자마자
자신
잠깐
잠시
저
저것
저것만큼
저기
저쪽
저희
전부
전자
전후
점에서 보아
정도에 이르다
제
제각기
제외하고
조금
조차
조차도
졸졸
좀
좋아
좍좍
주룩주룩
주저하지 않고
줄은 몰랏다
줄은모른다
중에서
중의하나
즈음하여
즉
즉시
지든지
지만
지말고
진짜로
쪽으로
차라리
참
참나
첫번째로
쳇
총적으로
총적으로 말하면
총적으로 보면
칠
콸콸
쾅쾅
쿵
타다
타인
탕탕
토하다
통하여
툭
퉤
틈타
팍
팔
퍽
펄렁
하
하게될것이다
하게하다
하겠는가
하고 있다
하고있었다
하곤하였다
하구나
하기 때문에
하기 위하여
하기는한데
하기만 하면
하기보다는
하기에
하나
하느니
하는 김에
하는 편이 낫다
하는것도
하는것만 못하다
하는것이 낫다
하는바
하더라도
하도다
하도록시키다
하도록하다
하든지
하려고하다
하마터면
하면 할수록
하면된다
하면서
하물며
하여금
하여야
하자마자
하지 않는다면
하지 않도록
하지마
하지마라
하지만
하하
한 까닭에
한 이유는
한 후
한다면
한다면 몰라도
한데
한마디
한적이있다
한켠으로는
한항목
할 따름이다
할 생각이다
할 줄 안다
할 지경이다
할 힘이 있다
할때
할만하다
할망정
할뿐
할수있다
할수있어
할줄알다
할지라도
할지언정
함께
해도된다
해도좋다
해봐요
해서는 안된다
해야한다
해요
했어요
향하다
향하여
향해서
허
허걱
허허
헉
헉헉
헐떡헐떡
형식으로 쓰여
혹시
혹은
혼자
훨씬
휘익
휴
흐흐
흥
힘입어'''

# %% [markdown]
# # 리스트 안에 들어가 있는지 확인하는 방법
# '강' in ['가','나','디','강']
# 리스트의 어떤 엘리먼트를 없애는 코드
# list = [1,2,3,4,5]
# list.remove(5)

# %%
ignore_list = ignore_list.split()
#if len(ignore_list) ==1:
        
for x in ['유','대','데','튜브',3,7]:
    ignore_list.append(x)

ind = ab_nouns.copy()

for b in ind:
    if b in ignore_list or len(b) == 1:
        ab_nouns.remove(b)
        
ab_target = ' '.join(ab_nouns)

# %%
ignore_list = ignore_list.split()
if len(ab_target) ==1:
        ab_target.remove()
for b in ind:
    if b in ignore_list:
        ab_nouns.remove(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 ignore_list = ignore_list.split()
#       2 if len(ab_target) ==1:
#       3         ab_target.remove()
#
# AttributeError: 'list' object has no attribute 'split'

# %% [markdown]
# # for 반복문으로 문자열 처리를 하면 안되겠다...ㅠ
# for i in ignore_list: #형태소만 쓸거면 (i, '') 도 가능
#     ab_target = ab_target.replace(i+' ','')

# %%
wc = WordCloud(background_color='white',font_path=r"C:\\Windows\\Fonts\\malgun.ttf").generate(ab_target)

# %%
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
#텍스트 불러오기
from os import path
#이미지파일 불러오기
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
import os
# 워드클라우드를 그리는 데 필요한 것, 사용하지 않을 단어 처리
from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
# 내 현재 폴더 경로 알아보기
#굳이 없어도 됨
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d, 'alice.txt')).read()

# open('alice.txt').readlines()[0]# text 문단별로 읽기
# open('alice.txt').read() # 파일 전체 읽기

# %%
a = open('alice.txt')

# %%
a.readline()
# Out:
# "Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, `and what is the use of a book,' thought Alice `without pictures or conversation?'\n"

# %%
a.readline()
# Out:
# 'So she was considering in her own mind (as well as she could, for the hot day made her feel very sleepy and stupid), whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her.\n'

# %%
# 파일을 통째로 안읽고 부분씩 읽을 수 있음
a = open('alice.txt')
temp = ' '
while temp != '':
    temp = a.readline()
    print(temp)
# Out:
# Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, `and what is the use of a book,' thought Alice `without pictures or conversation?'
#
# So she was considering in her own mind (as well as she could, for the hot day made her feel very sleepy and stupid), whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her.
#
#
#
# ...

# %%
# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
logo_mask = np.array(Image.open("cloud.jpg"))

# %%
STOPWORDS # 불용어사전

# %%
len(STOPWORDS)
# Out:
# 192

# %%
# wc 생성
stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=logo_mask, # 배경컬러, 최대 단어, 이미지
                stopwords=stopwords) #contour_width=3, contour_color='steelblue') # 불용어, 외곽선 지정, 외곽선 색상

# %%
# generate word cloud # 글자지정
wc.generate(text)

# %%
# store to file
#wc.to_file(path.join(d, "alice.png"))

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.show()
#plt.imshow(salary_mask, cmap=plt.cm.gray, interpolation='bilinear')
#plt.axis("off")

# %%
import matplotlib.pyplot as plt

# 그래프의 크기를 조정하여 Figure와 Axes를 생성합니다.
fig, ax = plt.subplots(figsize=(10, 2))

# 그래프를 생성합니다.
ax.plot([1, 2, 3, 4], [5, 1, 2, 3])

# 그래프를 이미지로 저장합니다. dpi는 인치당 도트 수입니다.
# plt.savefig('temp.png', dpi=300) #dpi : dot per inchies (해상도 조절)

# %% [markdown]
# ---
# # 워드클라우드 여러 효과 주기
# ---

# %%
from wordcloud import WordCloud, ImageColorGenerator

# %%
import os
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_gradient_magnitude

from wordcloud import WordCloud, ImageColorGenerator

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = os.path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# load image. This has been modified in gimp to be brighter and have more saturation.
parrot_color = np.array(Image.open(os.path.join(d, "WC.png")))
# subsample by factor of 3. Very lossy but for a wordcloud we don't really care.
parrot_color = parrot_color[::3, ::3]

# create mask  white is "masked out"
parrot_mask = parrot_color.copy()
#parrot_mask[parrot_mask.sum(axis=2) == 0] = 255

# some finesse: we enforce boundaries between colors so they get less washed out.
# For that we do some edge detection in the image
edges = np.mean([gaussian_gradient_magnitude(parrot_color[:, :, i] / 255., 2) for i in range(3)], axis=0)
parrot_mask[edges > .08] = 255

# create wordcloud. A bit sluggish, you can subsample more strongly for quicker rendering
# relative_scaling=0 means the frequencies in the data are reflected less
# acurately but it makes a better picture
wc = WordCloud(max_words=2000, mask=parrot_mask, max_font_size=40, random_state=42, relative_scaling=0)

# generate word cloud
wc.generate(text)
plt.imshow(wc)

# create coloring from image
image_colors = ImageColorGenerator(parrot_color)
wc.recolor(color_func=image_colors)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation="bilinear")
wc.to_file("parrot_new.png")

plt.figure(figsize=(10, 10))
plt.title("Original Image")
plt.imshow(parrot_color)

plt.figure(figsize=(10, 10))
plt.title("Edge map")
plt.imshow(edges)
plt.show()
