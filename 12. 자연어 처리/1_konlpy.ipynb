# %% [markdown]
# ---
# # 한국어 형태소 분석기(Konlpy) 실습
# ---

# %% [markdown]
# ### 토큰화 (Tokenization)
# : 주어진 텍스트를 단어 또는 문자 단위로 자르는 것

# %%
kor_text = "모든 국민은 그 보호하는 자녀에게 적어도 초등교육과 법률이 정하는 교육을 받게 할 의무를 진다. 공공필요에 의한 재산권의 수용·사용 또는 제한 및 그에 대한 보상은 법률로써 하되, 정당한 보상을 지급하여야 한다.국가유공자·상이군경 및 전몰군경의 유가족은 법률이 정하는 바에 의하여 우선적으로 근로의 기회를 부여받는다. 군인은 현역을 면한 후가 아니면 국무총리로 임명될 수 없다."

# %%
kor_text.split()
# Out:
# ['모든',
#  '국민은',
#  '그',
#  '보호하는',
#  '자녀에게',
#  '적어도',
#  '초등교육과',
#  '법률이',
#  '정하는',
#  '교육을',
#  '받게',
#  '할',
#  '의무를',
#  '진다.',
#  '공공필요에',
#  '의한',
#  '재산권의',
#  '수용·사용',
#  '또는',
#  '제한',
#  '및',
#  '그에',
#  '대한',
#  '보상은',
#  '법률로써',
#  '하되,',
#  '정당한',
#  '보상을',
#  '지급하여야',
#  '한다.국가유공자·상이군경',
#  '및',
#  '전몰군경의',
#  '유가족은',
#  '법률이',
#  '정하는',
#  '바에',
#  '의하여',
#  '우선적으로',
#  '근로의',
#  '기회를',
#  '부여받는다.',
#  '군인은',
#  '현역을',
#  '면한',
#  '후가',
#  '아니면',
#  '국무총리로',
#  '임명될',
#  '수',
#  '없다.']

# %% [markdown]
# ### 한국어 형태소 분석기
# https://konlpy.org/ko/latest/index.html

# %%
from konlpy.tag import Kkma
Kkma = Kkma()
Kkma.morphs("테스트 중입니다.")
# Out:
# ['테스트', '중', '이', 'ㅂ니다', '.']

# %%
from konlpy.tag import Okt
okt = Okt()
okt.morphs(kor_text)
# Out:
# ['모든',
#  '국민',
#  '은',
#  '그',
#  '보호',
#  '하는',
#  '자녀',
#  '에게',
#  '적어도',
#  '초등교육',
#  '과',
#  '법률',
#  '이',
#  '정',
#  '하는',
#  '교육',
#  '을',
#  '받게',
#  '할',
#  '의무',
#  '를',
#  '진다',
#  '.',
#  '공공필요',
#  '에',
#  '의한',
#  '재산권',
#  '의',
#  '수용',
#  '·',
#  '사용',
#  '또는',
#  '제한',
#  '및',
#  '그',
#  '에',
#  '대한',
#  '보상',
#  '은',
#  '법률',
#  '로써',
#  '하',
#  '되',
#  ',',
#  '정당한',
#  '보상',
#  '을',
#  '지급',
#  '하여야',
#  '한다',
#  '.',
#  '국가',
#  '유공',
#  '자',
#  '·',
#  '상이',
#  '군경',
#  '및',
#  '전몰',
#  '군',
#  '경의',
#  '유가족',
#  '은',
#  '법률',
#  '이',
#  '정',
#  '하는',
#  '바',
#  '에',
#  '의하여',
#  '우선',
#  '적',
#  '으로',
#  '근로',
#  '의',
#  '기회',
#  '를',
#  '부여',
#  '받는다',
#  '.',
#  '군인',
#  '은',
#  '현역',
#  '을',
#  '면',
#  '한',
#  '후',
#  '가',
#  '아니면',
#  '국무총리',
#  '로',
#  '임명',
#  '될',
#  '수',
#  '없다',
#  '.']

# %%
import pandas as pd
# ! pip install konlpy

# %% [markdown]
# ### konlpy - 한국어 말뭉치
#
# * kolaw : 대한민국 헌법 말뭉치
# * kobill : 국회법안 말뭉치

# %%
from konlpy.corpus import kolaw
kolaw.fileids()
# Out:
# ['constitution.txt']

# %%
c = kolaw.open('constitution.txt').read()
print(len(c))
print(c[:1000])
# Out:
# 18884
# 대한민국헌법
#
# 유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의·인도와 동포애로써 민족의 단결을 공고히 하고, 모든 사회적 폐습과 불의를 타파하며, 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치·경제·사회·문화의 모든 영역에 있어서 각인의 기회를 균등히 하고, 능력을 최고도로 발휘하게 하며, 자유와 권리에 따르는 책임과 의무를 완수하게 하여, 안으로는 국민생활의 균등한 향상을 기하고 밖으로는 항구적인 세계평화와 인류공영에 이바지함으로써 우리들과 우리들의 자손의 안전과 자유와 행복을 영원히 확보할 것을 다짐하면서 1948년 7월 12일에 제정되고 8차에 걸쳐 개정된 헌법을 이제 국회의 의결을 거쳐 국민투표에 의하여 개정한다.
#
#        제1장 총강
#   제1조 ① 대한민국은 민주공화국이다.
# ②대한민국의 주권은 국민에게 있고, 모든 권력은 국민으로부터 나온다.
#   제2조 ① 대한민국의 국민이 되는 요건은 법률로 정한다.
# ②국가는 법률이 정하는 바에 의하여 재외국민을 보호할 의무를 진다.
#   제3조 대한민국의 영토는 한반도와 그 부속도서로 한다.
#   제4조 대한민국은 통일을 지향하며, 자유민주적 기본질서에 입각한 평화적 통일 정책을 수립하고 이를 추진한다.
#   제5조 ① 대한민국은 국제평화의 유지에 노력하고 침략적 전쟁을 부인한다.
# ②국군은 국가의 안전보장과 국토방위의 신성한 의무를 수행함을 사명으로 하며, 그 정치적 중립성은 준수된다.
#   제6조 ① 헌법에 의하여 체결·공포된 조약과 일반적으로 승인된 국제법규는 국내법과 같은 효력을 가진다.
# ②외국인은 국제법과 조약이 정하는 바에 의하여 그 지위가 보장된다.
#   제7조 ① 공무원은 국민전체에 대한 봉사자이며, 국민에 대하여 책임을 진다.
# ②공무원의 신분과 정치적 중립성은 법률이 정하는 바에 의하여 보장된다.
#   제8조 ① 정당의 설립은 자유이며, 복수정당제

# %%
from konlpy.corpus import kobill
kobill.fileids()
# Out:
# ['1809890.txt',
#  '1809891.txt',
#  '1809892.txt',
#  '1809893.txt',
#  '1809894.txt',
#  '1809895.txt',
#  '1809896.txt',
#  '1809897.txt',
#  '1809898.txt',
#  '1809899.txt']

# %%
b = kobill.open('1809890.txt').read()
print(len(b))
print(b[:500])
# Out:
# 4201
# 지방공무원법 일부개정법률안
#
# (정의화의원 대표발의 )
#
#  의 안
#  번 호
#
# 9890
#
# 발의연월일 : 2010.  11.  12.
#
# 발  의  자 : 정의화․이명수․김을동
#
# 이사철․여상규․안규백
#
# 황영철․박영아․김정훈
#
# 김학송 의원(10인)
#
# 제안이유 및 주요내용
#
#   초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요
#
# 한 나이이나, 현재 공무원이 자녀를 양육하기 위하여 육아휴직을 할
#
# 수 있는 자녀의 나이는 만 6세 이하로 되어 있어 초등학교 저학년인
#
# 자녀를 돌보기 위해서는 해당 부모님은 일자리를 그만 두어야 하고
#
# 이는 곧 출산의욕을 저하시키는 문제로 이어질 수 있을 것임.
#
#   따라서 육아휴직이 가능한 자녀의 연령을 만 8세 이하로 개정하려
#
# 는 것임(안 제63조제2항제4호).
#
# - 1 -
#
# 법률  제        호
#
# 지방공무원법 일부개정법률안
#
# 지방공무원법 일부를 다음과 같이 개정한다.
#
# 제63조제2항제4호 중 “만 6세 이하의 초등학교 취학 전 자

# %% [markdown]
# ---
# 문장 분리
#
# ---

# %%
# ! pip install nltk
import nltk
# nltk.download()

# %%
from nltk import sent_tokenize

# %%
sentences = sent_tokenize(c)
sentences[:5]
# Out:
# ['대한민국헌법\n\n유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의·인도와 동포애로써 민족의 단결을 공고히 하고, 모든 사회적 폐습과 불의를 타파하며, 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치·경제·사회·문화의 모든 영역에 있어서 각인의 기회를 균등히 하고, 능력을 최고도로 발휘하게 하며, 자유와 권리에 따르는 책임과 의무를 완수하게 하여, 안으로는 국민생활의 균등한 향상을 기하고 밖으로는 항구적인 세계평화와 인류공영에 이바지함으로써 우리들과 우리들의 자손의 안전과 자유와 행복을 영원히 확보할 것을 다짐하면서 1948년 7월 12일에 제정되고 8차에 걸쳐 개정된 헌법을 이제 국회의 의결을 거쳐 국민투표에 의하여 개정한다.',
#  '제1장 총강\n  제1조 ① 대한민국은 민주공화국이다.',
#  '②대한민국의 주권은 국민에게 있고, 모든 권력은 국민으로부터 나온다.',
#  '제2조 ① 대한민국의 국민이 되는 요건은 법률로 정한다.',
#  '②국가는 법률이 정하는 바에 의하여 재외국민을 보호할 의무를 진다.']

# %%
sentence = sentences[5]
sentence
# Out:
# '제3조 대한민국의 영토는 한반도와 그 부속도서로 한다.'

# %% [markdown]
# ### konlpy 형태소 분석
#
# * morphs : 형태소 추출
# * pos : 품사 태깅
# * nouns : 명사만 추출

# %%
from konlpy.tag import Kkma, Hannanum, Komoran, Okt

hannanum= Hannanum()
kkma= Kkma()
komoran= Komoran()
okt= Okt()

# %% [markdown]
# 형태소 추출 (morphs)

# %%
# hannanum : KAIST SWRC(Semantic Web Research Center)에서 개발
hannanum.morphs(sentence)
# Out:
# ['제3조', '대한민국', '의', '영토', '는', '한반도', '와', '그', '부속도서', '로', '하', 'ㄴ다', '.']

# %%
# KKma : 서울대학교 IDS(intelligent Data Systems) 연구실에서 개발
kkma.morphs(sentence)
# Out:
# ['저',
#  '의',
#  '3',
#  '조',
#  '대한민국',
#  '의',
#  '영토',
#  '는',
#  '한반도',
#  '와',
#  '그',
#  '부속',
#  '도',
#  '서로',
#  '하',
#  'ㄴ다',
#  '.']

# %%
# Komoran
komoran.morphs(sentence)
# Out:
# ['제',
#  '3',
#  '조',
#  '대한민국',
#  '의',
#  '영토',
#  '는',
#  '한반도',
#  '와',
#  '그',
#  '부속',
#  '도서',
#  '로',
#  '하',
#  'ㄴ다',
#  '.']

# %%
# okt: 오픈 소스 한국어 분석기, 과거 트위터 형태소 분석기
okt.morphs(sentence)
# Out:
# ['제',
#  '3조',
#  '대한민국',
#  '의',
#  '영토',
#  '는',
#  '한반도',
#  '와',
#  '그',
#  '부속',
#  '도서',
#  '로',
#  '한다',
#  '.']

# %%
# nsmc 데이터 로드
# 'https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt'
train_data = pd.read_csv('https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt', sep='\t', encoding='utf-8')
train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
# N번째 문서 가져오기
sample_data2 = train_data.iloc[100]['document']
sample_data2
# Out:
# '신카이 마코토의 작화와,미유와 하나카나가 연기를 잘해줘서 더대박이였다.'

# %%
# compare_morphs method 만들기 -> 한 번에 모든 morphs 를 볼 수 있게 출력해보기
def compare_morphs(sample_data):
    print(f'hannanum: {hannanum.morphs(sample_data)}')
    print(f'kkma: {kkma.morphs(sample_data)}')
    print(f'komoran: {komoran.morphs(sample_data)}')
    print(f'okt: {okt.morphs(sample_data)}')

# %%
# 실행
compare_morphs(sample_data2)
# Out:
# hannanum: ['신', '카', '이', '마코토', '의', '작화와,미유', '와', '하나카나', '가', '연기', '를', '잘하', '어', '주', '어서', '더대박이', '이', '었다', '.']
# kkma: ['신', '카이', '마코토', '의', '작화', '와', ',', '미', '유', '와', '하나', '카나', '가', '연기', '를', '잘하', '어', '주', '어서', '더', '대', '박이', '이', '었', '다', '.']
# komoran: ['신카이 마코토', '의', '작화', '와', ',', '미', '유', '와', '하나', '카나', '가', '연기', '를', '잘', '하', '아', '주', '어서', '더', '대박', '이', '이', '었', '다', '.']
# okt: ['신카이', '마코토', '의', '작화', '와', ',', '미', '유', '와', '하나', '카나', '가', '연기', '를', '잘', '해줘서', '더', '대박', '이', '였다', '.']

# %% [markdown]
# 품사 태깅 (Pos)

# %%
# compare_pos method 만들기 -> 한 번에 모든 pos 를 볼 수 있게 출력해보기
def compare_pos(sample_data):
    print(f'hannanum: {hannanum.pos(sample_data)}')
    print(f'kkma: {kkma.pos(sample_data)}')
    print(f'komoran: {komoran.pos(sample_data)}')
    print(f'okt: {okt.pos(sample_data)}')

# %%
# 실행
compare_pos(sample_data2)
# Out:
# hannanum: [('신', 'X'), ('카', 'N'), ('이', 'J'), ('마코토', 'N'), ('의', 'J'), ('작화와,미유', 'N'), ('와', 'J'), ('하나카나', 'N'), ('가', 'J'), ('연기', 'N'), ('를', 'J'), ('잘하', 'P'), ('어', 'E'), ('주', 'P'), ('어서', 'E'), ('더대박이', 'N'), ('이', 'J'), ('었다', 'E'), ('.', 'S')]
# kkma: [('신', 'NNG'), ('카이', 'UN'), ('마코토', 'NNG'), ('의', 'JKG'), ('작화', 'NNG'), ('와', 'JKM'), (',', 'SP'), ('미', 'NNG'), ('유', 'NNG'), ('와', 'JKM'), ('하나', 'NNG'), ('카나', 'NNG'), ('가', 'JKS'), ('연기', 'NNG'), ('를', 'JKO'), ('잘하', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('어서', 'ECD'), ('더', 'MAG'), ('대', 'NNG'), ('박이', 'NNG'), ('이', 'VCP'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF')]
# komoran: [('신카이 마코토', 'NNP'), ('의', 'JKG'), ('작화', 'NNP'), ('와', 'JC'), (',', 'SP'), ('미', 'NNP'), ('유', 'NNP'), ('와', 'JC'), ('하나', 'NR'), ('카나', 'NNP'), ('가', 'JKS'), ('연기', 'NNG'), ('를', 'JKO'), ('잘', 'MAG'), ('하', 'XSV'), ('아', 'EC'), ('주', 'VX'), ('어서', 'EC'), ('더', 'NNG'), ('대박', 'NNP'), ('이', 'NNP'), ('이', 'VCP'), ('었', 'EP'), ('다', 'EF'), ('.', 'SF')]
# okt: [('신카이', 'Noun'), ('마코토', 'Noun'), ('의', 'Josa'), ('작화', 'Noun'), ('와', 'Josa'), (',', 'Punctuation'), ('미', 'Adjective'), ('유', 'Noun'), ('와', 'Josa'), ('하나', 'Noun'), ('카나', 'Noun'), ('가', 'Josa'), ('연기', 'Noun'), ('를', 'Josa'), ('잘', 'VerbPrefix'), ('해줘서', 'Verb'), ('더', 'Noun'), ('대박', 'Noun'), ('이', 'Josa'), ('였다', 'Verb'), ('.', 'Punctuation')]

# %% [markdown]
# 태그셋 확인 (tagset)

# %%
print(len(hannanum.tagset))
hannanum.tagset
# Out:
# 29
# {'E': '어미',
#  'EC': '연결 어미',
#  'EF': '종결 어미',
#  'EP': '선어말어미',
#  'ET': '전성 어미',
#  'F': '외국어',
#  'I': '독립언',
#  'II': '감탄사',
#  'J': '관계언',
#  'JC': '격조사',
#  'JP': '서술격 조사',
#  'JX': '보조사',
#  'M': '수식언',
#  'MA': '부사',
#  'MM': '관형사',
#  'N': '체언',
#  'NB': '의존명사',
#  'NC': '보통명사',
#  'NN': '수사',
#  'NP': '대명사',
#  'NQ': '고유명사',
#  'P': '용언',
#  'PA': '형용사',
#  'PV': '동사',
#  'PX': '보조 용언',
#  'S': '기호',
#  'X': '접사',
#  'XP': '접두사',
#  'XS': '접미사'}

# %%
print(len(kkma.tagset))
kkma.tagset
# Out:
# 67
# {'EC': '연결 어미',
#  'ECD': '의존적 연결 어미',
#  'ECE': '대등 연결 어미',
#  'ECS': '보조적 연결 어미',
#  'EF': '종결 어미',
#  'EFA': '청유형 종결 어미',
#  'EFI': '감탄형 종결 어미',
#  'EFN': '평서형 종결 어미',
#  'EFO': '명령형 종결 어미',
#  'EFQ': '의문형 종결 어미',
#  'EFR': '존칭형 종결 어미',
#  'EP': '선어말 어미',
#  'EPH': '존칭 선어말 어미',
#  'EPP': '공손 선어말 어미',
#  'EPT': '시제 선어말 어미',
#  'ET': '전성 어미',
#  'ETD': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JK': '조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKI': '호격 조사',
#  'JKM': '부사격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JX': '보조사',
#  'MA': '부사',
#  'MAC': '접속 부사',
#  'MAG': '일반 부사',
#  'MD': '관형사',
#  'MDN': '수 관형사',
#  'MDT': '일반 관형사',
#  'NN': '명사',
#  'NNB': '일반 의존 명사',
#  'NNG': '보통명사',
#  'NNM': '단위 의존 명사',
#  'NNP': '고유명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'OH': '한자',
#  'OL': '외국어',
#  'ON': '숫자',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
#  'SW': '기타기호 (논리수학기호,화폐기호)',
#  'UN': '명사추정범주',
#  'VA': '형용사',
#  'VC': '지정사',
#  'VCN': "부정 지정사, 형용사 '아니다'",
#  'VCP': "긍정 지정사, 서술격 조사 '이다'",
#  'VV': '동사',
#  'VX': '보조 용언',
#  'VXA': '보조 형용사',
#  'VXV': '보조 동사',
#  'XP': '접두사',
#  'XPN': '체언 접두사',
#  'XPV': '용언 접두사',
#  'XR': '어근',
#  'XSA': '형용사 파생 접미사',
#  'XSN': '명사파생 접미사',
#  'XSV': '동사 파생 접미사'}

# %%
print(len(komoran.tagset))
komoran.tagset
# Out:
# 45
# {'EC': '연결 어미',
#  'EF': '종결 어미',
#  'EP': '선어말어미',
#  'ETM': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JKB': '부사격 조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JKV': '호격 조사',
#  'JX': '보조사',
#  'MAG': '일반 부사',
#  'MAJ': '접속 부사',
#  'MM': '관형사',
#  'NA': '분석불능범주',
#  'NF': '명사추정범주',
#  'NNB': '의존 명사',
#  'NNG': '일반 명사',
#  'NNP': '고유 명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'NV': '용언추정범주',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SH': '한자',
#  'SL': '외국어',
#  'SN': '숫자',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
#  'SW': '기타기호 (논리수학기호,화폐기호)',
#  'VA': '형용사',
#  'VCN': '부정 지정사',
#  'VCP': '긍정 지정사',
#  'VV': '동사',
#  'VX': '보조 용언',
#  'XPN': '체언 접두사',
#  'XR': '어근',
#  'XSA': '형용사 파생 접미사',
#  'XSN': '명사파생 접미사',
#  'XSV': '동사 파생 접미사'}

# %%
print(len(okt.tagset))
okt.tagset
# Out:
# 19
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %% [markdown]
# 명사 추출 (nouns)

# %%
# compare_nouns method 만들기 -> 한 번에 모든 명사를 볼 수 있게 출력해보기
def compare_nouns(sample_data):
    print(f'hannanum: {hannanum.nouns(sample_data)}')
    print(f'kkma: {kkma.nouns(sample_data)}')
    print(f'komoran: {komoran.nouns(sample_data)}')
    print(f'okt: {okt.nouns(sample_data)}')

# %%
# 실행
compare_nouns(sample_data2)
# Out:
# hannanum: ['카', '마코토', '작화와,미유', '하나카나', '연기', '더대박이']
# kkma: ['신', '신카이', '카이', '마코토', '작화', '미', '미유', '유', '하나', '하나카나', '카나', '연기', '대', '대박이', '박이']
# komoran: ['신카이 마코토', '작화', '미', '유', '카나', '연기', '더', '대박', '이']
# okt: ['신카이', '마코토', '작화', '유', '하나', '카나', '연기', '더', '대박']

# %% [markdown]
# ### 불용어 제거하기

# %%
stop_words = ['은', '는', '이', '가', '을', '를', '의', '더', '잘', '.', ',', '와']

word_tokens = kkma.morphs(sample_data2)

# 불용어 제거
remove_tokens = [word for word in word_tokens if word not in stop_words]
print(word_tokens)
print(remove_tokens)
# Out:
# ['신', '카이', '마코토', '의', '작화', '와', ',', '미', '유', '와', '하나', '카나', '가', '연기', '를', '잘하', '어', '주', '어서', '더', '대', '박이', '이', '었', '다', '.']
# ['신', '카이', '마코토', '작화', '미', '유', '하나', '카나', '연기', '잘하', '어', '주', '어서', '대', '박이', '었', '다']

# %% [markdown]
# ### 사용자 사전 추가

# %%
# !pip install customized_konlpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting customized_konlpy
#   Obtaining dependency information for customized_konlpy from https://files.pythonhosted.org/packages/07/8c/d39c483b637a6d85ab2d6da50012810628982bbd5279818bdc5dd1e7da51/customized_konlpy-0.0.64-py3-none-any.whl.metadata
#   Downloading customized_konlpy-0.0.64-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Jpype1>=0.6.1 in c:\users\big3-05\appdata\roaming\python\python311\site-packages (from customized_konlpy) (1.5.0)
# Requirement already satisfied: konlpy>=0.4.4 in c:\users\big3-05\appdata\roaming\python\python311\site-packages (from customized_konlpy) (0.6.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from Jpype1>=0.6.1->customized_konlpy) (23.1)
# Requirement already satisfied: lxml>=4.1.0 in c:\programdata\anaconda3\lib\site-packages (from konlpy>=0.4.4->customized_konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in c:\users\big3-05\appdata\roaming\python\python311\site-packages (from konlpy>=0.4.4->customized_konlpy) (1.26.1)
# Downloading customized_konlpy-0.0.64-py3-none-any.whl (881 kB)
#    ---------------------------------------- 0.0/881.5 kB ? eta -:--:--
#    ---------------------------------------- 10.2/881.5 kB ? eta -:--:--
#    ----- ---------------------------------- 112.6/881.5 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 881.5/881.5 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: customized_konlpy
# Successfully installed customized_konlpy-0.0.64

# %%
from ckonlpy.tag import Twitter

# %%
# 형태소 추출 : morphs
twitter = Twitter()
twitter.morphs(sample_data2)
# Out:
# C:\Users\BIG3-05\AppData\Roaming\Python\Python311\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# ['신카이',
#  '마코토',
#  '의',
#  '작화',
#  '와',
#  ',',
#  '미',
#  '유',
#  '와',
#  '하나',
#  '카나',
#  '가',
#  '연기',
#  '를',
#  '잘',
#  '해줘서',
#  '더',
#  '대박',
#  '이',
#  '였다',
#  '.']

# %%
# 사용자 사전 추가
twitter.add_dictionary('신카이 마코토', 'Noun')
twitter.add_dictionary('미유', 'Noun')
twitter.add_dictionary('하나카나', 'Noun')

# %%
# 다시 한 번 형태소 추출
twitter.morphs(sample_data2)
# Out:
# ['신카이',
#  '마코토',
#  '의',
#  '작화',
#  '와',
#  ',',
#  '미유',
#  '와',
#  '하나카나',
#  '가',
#  '연기',
#  '를',
#  '잘',
#  '해줘서',
#  '더',
#  '대박',
#  '이',
#  '였다',
#  '.']

# %% [markdown]
# ### 품사, 명사 별 count 하기, 기초 시각화

# %%
# train_data에 대해 품사 별 count 하기
# {'Noun': 500, 'Adverb': 44652...}
# okt 활용
test = train_data['document'][:1000]

# 빈 딕셔너리 생성
pos_counts = {}

# 각 문장을 형태소 단위로 분리하여 품사 태깅 후, 품사 count
for sentence in test:
    pos_tags = okt.pos(sentence)
    for _, pos in pos_tags:
        if pos in pos_counts:
            pos_counts[pos] += 1
        else:
            pos_counts[pos] = 1

print(pos_counts)

# {'Adjective': 189508, 'Adverb': 44652, 'Alpha': 12954, 'Conjunction': 4135, 'Determiner': 17825, 'Eomi': 518, 'Exclamation': 6353, 'Foreign': 6605, 'Hashtag': 4, 'Josa': 360544, 'KoreanParticle': 27531, 'Noun': 896632, 'Number': 27229, 'PreEomi': 14, 'Punctuation': 204877, 'ScreenName': 5, 'Suffix': 46007, 'Unknown': 0, 'Verb': 266856, 'Modifier': 32968, 'VerbPrefix': 10894, 'URL': 48, 'Email': 9}
# Out:
# {'Exclamation': 45, 'Noun': 6101, 'Punctuation': 1385, 'Adjective': 1319, 'Josa': 2407, 'Verb': 1816, 'Modifier': 238, 'Adverb': 290, 'Determiner': 119, 'Number': 171, 'KoreanParticle': 189, 'VerbPrefix': 84, 'Suffix': 329, 'Foreign': 49, 'Alpha': 75, 'Eomi': 4, 'Conjunction': 24, 'PreEomi': 1}

# %%
# train_data에 대해 품사 별 count 하기
pos_dict = {}
for tag in okt.tagset.keys():
    pos_dict[tag] = 0
print(pos_dict)

for doc in train_data['document'][:1000]:
    doc_pos = okt.pos(str(doc))
    for uni_pos in doc_pos:
        pos = uni_pos[1]
        if pos in pos_dict:
            pos_dict[pos] += 1
        else:
            pos_dict[pos] = 1
print(pos_dict)
# Out:
# {'Adjective': 0, 'Adverb': 0, 'Alpha': 0, 'Conjunction': 0, 'Determiner': 0, 'Eomi': 0, 'Exclamation': 0, 'Foreign': 0, 'Hashtag': 0, 'Josa': 0, 'KoreanParticle': 0, 'Noun': 0, 'Number': 0, 'PreEomi': 0, 'Punctuation': 0, 'ScreenName': 0, 'Suffix': 0, 'Unknown': 0, 'Verb': 0}
# {'Adjective': 1319, 'Adverb': 290, 'Alpha': 75, 'Conjunction': 24, 'Determiner': 119, 'Eomi': 4, 'Exclamation': 45, 'Foreign': 49, 'Hashtag': 0, 'Josa': 2407, 'KoreanParticle': 189, 'Noun': 6101, 'Number': 171, 'PreEomi': 1, 'Punctuation': 1385, 'ScreenName': 0, 'Suffix': 329, 'Unknown': 0, 'Verb': 1816, 'Modifier': 238, 'VerbPrefix': 84}

# %%
# plot.bar 그려보기
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc('font', family='Malgun Gothic')
mpl.rcParams['axes.unicode_minus'] = False

# 한국어가 적힌 데이터를 시각화 하기 위한 기본 설정

plt.bar(pos_dict.keys(), pos_dict.values())
plt.xlabel('품사')
plt.ylabel('개수')
plt.title('품사별 개수')
plt.xticks(rotation=90)  # x축 레이블 회전
plt.show()

# %%
pd.DataFrame(pos_dict.values(), pos_dict.keys(), columns=['counting']).plot.bar()
# Out:
# <Axes: >

# %%
#!pip install wordcloud koreanize_matplotlib

# %%
# 명사별 수치 count 시각화
noun_dict = {}

# 각 문장에 대해 형태소 분석하여 품사 count
for doc in train_data['document'][:1000]:
    doc_pos = kkma.pos(str(doc))
    for _, pos in doc_pos:
        if 'NN' in pos:  # 품사가 'NNG'를 포함하는지 확인
            if pos in noun_dict:
                noun_dict[pos] += 1
            else:
                noun_dict[pos] = 1

print(noun_dict)
# Out:
# {'NNG': 5142, 'NNB': 436, 'NNM': 141, 'NNP': 65}

# %%
# !pip install koreanize_matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting koreanize_matplotlib
#   Obtaining dependency information for koreanize_matplotlib from https://files.pythonhosted.org/packages/ef/91/93f56a4526d2dbead44250d9166d97568c2ce051c90eaa4be36788d59131/koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from koreanize_matplotlib) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\big3-05\appdata\roaming\python\python311\site-packages (from matplotlib->koreanize_matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.16.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.9 MB 653.6 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/7.9 MB 4.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.8/7.9 MB 37.2 MB/s eta 0:00:01
#    ---------------------------------------  7.9/7.9 MB 46.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 39.1 MB/s eta 0:00:00
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %%
# 명사별 수치 count 시각화
from nltk import Text 
import matplotlib.pyplot as plt
import koreanize_matplotlib

all_reviews = ' '.join(train_data['document'][:1000].astype('str'))
rn = Text(okt.nouns(all_reviews), name = 'N')
rn.plot(30)
plt.show()

# %%
# wordcloud 그려보기
from wordcloud import WordCloud
import matplotlib.pyplot as plt

font_path = 'C:\\Windows\\Fonts\\batang.TTC'

wc = WordCloud(width=1000, height=1000, background_color='white', font_path=font_path)
plt.imshow(wc.generate_from_frequencies(rn.vocab()))
plt.axis("off")
plt.show()
